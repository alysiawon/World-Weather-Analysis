# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import numpy as np
import timeit

# %%
# # Import API
import requests
from config import weather_api_key
from citipy import citipy

# %%
# Step 1: Create a new set of 2,000 random latitudes and longitudes

# Generate random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Zip latitudes and longitudes together
lat_longs = zip(lats, longs)

# Create coordinates
coordinates = list(lat_longs)
len(coordinates)
# Out:
# 2000

# %%
# Step 2: Get the nearest city using the citipy module.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# City Count
len(cities)
# Out:
# 740

# %%
# Step 3: Perform an API call with the OpenWeatherMap.

# URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 4: Retrieve the following information from the API call:

# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ord 37 of Set 20 | grand forks
# Processing Record 38 of Set 20 | peterhead
# Processing Record 39 of Set 20 | banda aceh
# Processing Record 40 of Set 20 | oistins
# Processing Record 41 of Set 20 | mackay
# Processing Record 42 of Set 20 | mizpe ramon
# City not found. Skipping...
# Processing Record 43 of Set 20 | lavrentiya
# Processing Record 44 of Set 20 | hauterive
# Processing Record 45 of Set 20 | butaritari
# Processing Record 46 of Set 20 | doka
# Processing Record 47 of Set 20 | bukachacha
# Processing Record 48 of Set 20 | itaqui
# Processing Record 49 of Set 20 | hambantota
# Processing Record 50 of Set 20 | ziro
# Processing Record 1 of Set 21 | alekseyevsk
# Processing Record 2 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 21 | chuy
# Processing Record 4 of Set 21 | san jose de gracia
# Processing Record 5 of Set 21 | aksu
# Processing Record 6 of Set 21 | dumas
# Processing Record 7 of Set 21 | pudem
# Processing Record 8 of Set 21 | komsomolskiy
# Processing Record 9 of Set 21 | deputatskiy
# Processing Record 10 of Set 21 | ler
# Processing Record 11 of Set 21 | san cristobal
# Processing Record 12 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 21 | pirawa
# Processing Record 14 of Set 21 | havre-saint-pierre
# Processing Record 15 of Set 21 | semey
# Processing Record 16 of Set 21 | okha
# Processing Record 17 of Set 21 | fort nelson
# Processing Record 18 of Set 21 | isangel
# Processing Record 19 of Set 21 | grand gaube
# Processing Record 20 of Set 21 | katsuura
# Processing Record 21 of Set 21 | kavaratti
# Processing Record 22 of Set 21 | bolshoye kozino
# City not found. Skipping...
# Processing Record 23 of Set 21 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 21 | macherla
# Processing Record 25 of Set 21 | victoria
# Processing Record 26 of Set 21 | villany
# Processing Record 27 of Set 21 | west bay
# Processing Record 28 of Set 21 | vila do maio
# Processing Record 29 of Set 21 | nizhnevartovsk
# Processing Record 30 of Set 21 | jacqueville
# Processing Record 31 of Set 21 | moba
# Processing Record 32 of Set 21 | port-gentil
# Processing Record 33 of Set 21 | guaruja
# Processing Record 34 of Set 21 | sioux lookout
# Processing Record 35 of Set 21 | takoradi
# Processing Record 36 of Set 21 | hofn
# Processing Record 37 of Set 21 | arrifes
# Processing Record 38 of Set 21 | narsaq
# Processing Record 39 of Set 21 | ambulu
# Processing Record 40 of Set 21 | karpathos
# Processing Record 41 of Set 21 | shubarkuduk
# Processing Record 42 of Set 21 | khorixas
# Processing Record 43 of Set 21 | porto santo
# Processing Record 44 of Set 21 | jasper
# Processing Record 45 of Set 21 | tuatapere
# Processing Record 46 of Set 21 | diamantino
# Processing Record 47 of Set 21 | sugal
# Processing Record 48 of Set 21 | chara
# Processing Record 49 of Set 21 | kapit
# Processing Record 50 of Set 21 | yeppoon
# Processing Record 1 of Set 22 | alice springs
# Processing Record 2 of Set 22 | yanchukan
# City not found. Skipping...
# Processing Record 3 of Set 22 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 22 | colares
# Processing Record 5 of Set 22 | amuntai
# Processing Record 6 of Set 22 | kalabo
# Processing Record 7 of Set 22 | ponta delgada
# Processing Record 8 of Set 22 | hammerfest
# Processing Record 9 of Set 22 | zyryanka
# Processing Record 10 of Set 22 | beloha
# Processing Record 11 of Set 22 | virginia beach
# Processing Record 12 of Set 22 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 22 | pacific grove
# Processing Record 14 of Set 22 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 22 | rocha
# Processing Record 16 of Set 22 | jackson
# Processing Record 17 of Set 22 | maarianhamina
# Processing Record 18 of Set 22 | ayan
# Processing Record 19 of Set 22 | kaeo
# Processing Record 20 of Set 22 | mount gambier
# Processing Record 21 of Set 22 | tsumeb
# Processing Record 22 of Set 22 | college
# Processing Record 23 of Set 22 | masallatah
# Processing Record 24 of Set 22 | cidreira
# Processing Record 25 of Set 22 | zlobin
# Processing Record 26 of Set 22 | luganville
# Processing Record 27 of Set 22 | obera
# Processing Record 28 of Set 22 | kippen
# Processing Record 29 of Set 22 | kolyvan
# Processing Record 30 of Set 22 | grand-santi
# Processing Record 31 of Set 22 | linxia
# Processing Record 32 of Set 22 | taga
# Processing Record 33 of Set 22 | campagna
# Processing Record 34 of Set 22 | maniitsoq
# Processing Record 35 of Set 22 | envira
# Processing Record 36 of Set 22 | stornoway
# Processing Record 37 of Set 22 | flin flon
# Processing Record 38 of Set 22 | yulara
# Processing Record 39 of Set 22 | lakatoro
# Processing Record 40 of Set 22 | abu samrah
# Processing Record 41 of Set 22 | hamilton
# Processing Record 42 of Set 22 | coquimbo
# Processing Record 43 of Set 22 | chakwal
# Processing Record 44 of Set 22 | manubul
# Processing Record 45 of Set 22 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 22 | severo-kurilsk
# Processing Record 47 of Set 22 | ust-kishert
# Processing Record 48 of Set 22 | yurginskoye
# Processing Record 49 of Set 22 | abalak
# Processing Record 50 of Set 22 | parchim
# Processing Record 1 of Set 23 | ixtapa
# Processing Record 2 of Set 23 | huatulco
# Processing Record 3 of Set 23 | mizdah
# Processing Record 4 of Set 23 | vredendal
# Processing Record 5 of Set 23 | iskateley
# Processing Record 6 of Set 23 | caraquet
# Processing Record 7 of Set 23 | lagoa
# Processing Record 8 of Set 23 | sosnogorsk
# Processing Record 9 of Set 23 | soltsy
# Processing Record 10 of Set 23 | bubaque
# Processing Record 11 of Set 23 | gizo
# Processing Record 12 of Set 23 | mountain home
# Processing Record 13 of Set 23 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 23 | druskininkai
# Processing Record 15 of Set 23 | xiongzhou
# Processing Record 16 of Set 23 | kem
# Processing Record 17 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 23 | vostok
# Processing Record 19 of Set 23 | bilibino
# Processing Record 20 of Set 23 | saint-pierre
# Processing Record 21 of Set 23 | arinos
# Processing Record 22 of Set 23 | lompoc
# Processing Record 23 of Set 23 | progreso
# Processing Record 24 of Set 23 | mabaruma
# Processing Record 25 of Set 23 | makakilo city
# Processing Record 26 of Set 23 | chimbote
# Processing Record 27 of Set 23 | atasu
# Processing Record 28 of Set 23 | berberati
# Processing Record 29 of Set 23 | kropotkin
# Processing Record 30 of Set 23 | lensk
# Processing Record 31 of Set 23 | mercedes
# Processing Record 32 of Set 23 | kaseda
# Processing Record 33 of Set 23 | guerrero negro
# Processing Record 34 of Set 23 | fairbanks
# Processing Record 35 of Set 23 | yeroham
# Processing Record 36 of Set 23 | turukhansk
# Processing Record 37 of Set 23 | karacakoy
# Processing Record 38 of Set 23 | dali
# Processing Record 39 of Set 23 | novyy urgal
# Processing Record 40 of Set 23 | yumen
# Processing Record 41 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 23 | menongue
# Processing Record 43 of Set 23 | batemans bay
# Processing Record 44 of Set 23 | acarau
# Processing Record 45 of Set 23 | antofagasta
# Processing Record 46 of Set 23 | sergeyevka
# Processing Record 47 of Set 23 | benghazi
# Processing Record 48 of Set 23 | noumea
# Processing Record 49 of Set 23 | mount isa
# Processing Record 50 of Set 23 | pathein
# Processing Record 1 of Set 24 | yenagoa
# Processing Record 2 of Set 24 | buta
# Processing Record 3 of Set 24 | lahat
# Processing Record 4 of Set 24 | nova bana
# Processing Record 5 of Set 24 | jalu
# Processing Record 6 of Set 24 | pak phanang
# Processing Record 7 of Set 24 | high prairie
# Processing Record 8 of Set 24 | riyadh
# Processing Record 9 of Set 24 | pemberton
# Processing Record 10 of Set 24 | basco
# Processing Record 11 of Set 24 | bowen
# Processing Record 12 of Set 24 | talnakh
# Processing Record 13 of Set 24 | usinsk
# Processing Record 14 of Set 24 | kihei
# Processing Record 15 of Set 24 | kutum
# Processing Record 16 of Set 24 | vaxjo
# Processing Record 17 of Set 24 | marsa matruh
# Processing Record 18 of Set 24 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 24 | vila franca do campo
# Processing Record 20 of Set 24 | galle
# Processing Record 21 of Set 24 | bereznik
# Processing Record 22 of Set 24 | kudahuvadhoo
# Processing Record 23 of Set 24 | nedjo
# Processing Record 24 of Set 24 | simplicio mendes
# Processing Record 25 of Set 24 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 24 | lumeje
# Processing Record 27 of Set 24 | ardesen
# Processing Record 28 of Set 24 | swellendam
# Processing Record 29 of Set 24 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 24 | muroto
# Processing Record 31 of Set 24 | kamina
# Processing Record 32 of Set 24 | sakakah
# Processing Record 33 of Set 24 | waingapu
# Processing Record 34 of Set 24 | constitucion
# Processing Record 35 of Set 24 | veraval
# Processing Record 36 of Set 24 | poso
# Processing Record 37 of Set 24 | winnemucca
# Processing Record 38 of Set 24 | eyl
# Processing Record 39 of Set 24 | hefei
# Processing Record 40 of Set 24 | luanda
# Processing Record 41 of Set 24 | belyy yar
# Processing Record 42 of Set 24 | bantry
# Processing Record 43 of Set 24 | kurumkan
# Processing Record 44 of Set 24 | murgab
# Processing Record 45 of Set 24 | ola
# Processing Record 46 of Set 24 | norfolk
# Processing Record 47 of Set 24 | laguna
# Processing Record 48 of Set 24 | westport
# Processing Record 49 of Set 24 | channel-port aux basques
# Processing Record 50 of Set 24 | coari
# Processing Record 1 of Set 25 | sovetskaya gavan
# Processing Record 2 of Set 25 | camalu
# Processing Record 3 of Set 25 | micheweni
# Processing Record 4 of Set 25 | naze
# Processing Record 5 of Set 25 | alyangula
# Processing Record 6 of Set 25 | beipiao
# Processing Record 7 of Set 25 | the valley
# Processing Record 8 of Set 25 | peddapalli
# Processing Record 9 of Set 25 | pasni
# Processing Record 10 of Set 25 | kesennuma
# City not found. Skipping...
# Processing Record 11 of Set 25 | samarai
# Processing Record 12 of Set 25 | marzuq
# Processing Record 13 of Set 25 | lasa
# Processing Record 14 of Set 25 | kapuskasing
# Processing Record 15 of Set 25 | sola
# Processing Record 16 of Set 25 | manggar
# Processing Record 17 of Set 25 | cocula
# Processing Record 18 of Set 25 | grafton
# Processing Record 19 of Set 25 | port hawkesbury
# Processing Record 20 of Set 25 | yima
# Processing Record 21 of Set 25 | alcudia
# Processing Record 22 of Set 25 | ipira
# Processing Record 23 of Set 25 | nacala
# Processing Record 24 of Set 25 | fevik
# Processing Record 25 of Set 25 | taoudenni
# Processing Record 26 of Set 25 | palmer
# Processing Record 27 of Set 25 | kloulklubed
# Processing Record 28 of Set 25 | sisimiut
# Processing Record 29 of Set 25 | moose factory
# Processing Record 30 of Set 25 | biggar
# Processing Record 31 of Set 25 | chengde
# Processing Record 32 of Set 25 | talaya
# Processing Record 33 of Set 25 | moulmeingyun
# City not found. Skipping...
# Processing Record 34 of Set 25 | kuloy
# Processing Record 35 of Set 25 | bonavista
# Processing Record 36 of Set 25 | lively
# Processing Record 37 of Set 25 | amapa
# Processing Record 38 of Set 25 | winona
# Processing Record 39 of Set 25 | zhezkazgan
# Processing Record 40 of Set 25 | islamnagar
# Processing Record 41 of Set 25 | ardakan
# Processing Record 42 of Set 25 | kavieng
# Processing Record 43 of Set 25 | leh
# Processing Record 44 of Set 25 | huanuni
# Processing Record 45 of Set 25 | esik
# Processing Record 46 of Set 25 | aklavik
# Processing Record 47 of Set 25 | jvari
# Processing Record 48 of Set 25 | springbok
# Processing Record 49 of Set 25 | nantucket
# Processing Record 50 of Set 25 | bongandanga
# Processing Record 1 of Set 26 | kaili
# Processing Record 2 of Set 26 | sargodha
# Processing Record 3 of Set 26 | vao
# Processing Record 4 of Set 26 | akureyri
# Processing Record 5 of Set 26 | kamennogorsk
# Processing Record 6 of Set 26 | langham
# Processing Record 7 of Set 26 | santa rosa
# Processing Record 8 of Set 26 | gat
# Processing Record 9 of Set 26 | la palma del condado
# Processing Record 10 of Set 26 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 26 | marsh harbour
# Processing Record 12 of Set 26 | rundu
# Processing Record 13 of Set 26 | abu zabad
# Processing Record 14 of Set 26 | tauramena
# Processing Record 15 of Set 26 | pemba
# Processing Record 16 of Set 26 | iquique
# Processing Record 17 of Set 26 | xining
# Processing Record 18 of Set 26 | lethem
# Processing Record 19 of Set 26 | tambopata
# Processing Record 20 of Set 26 | erdenet
# Processing Record 21 of Set 26 | churapcha
# Processing Record 22 of Set 26 | aykhal
# Processing Record 23 of Set 26 | old shinyanga
# Processing Record 24 of Set 26 | ulladulla
# Processing Record 25 of Set 26 | flekkefjord
# Processing Record 26 of Set 26 | burica
# City not found. Skipping...
# Processing Record 27 of Set 26 | bam
# Processing Record 28 of Set 26 | laerdalsoyri
# Processing Record 29 of Set 26 | praia
# Processing Record 30 of Set 26 | pachino
# Processing Record 31 of Set 26 | lyaskelya
# Processing Record 32 of Set 26 | itarema
# Processing Record 33 of Set 26 | tavira
# Processing Record 34 of Set 26 | williamsburg
# Processing Record 35 of Set 26 | saravan
# Processing Record 36 of Set 26 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 26 | nouna
# Processing Record 38 of Set 26 | salina
# Processing Record 39 of Set 26 | calbuco
# Processing Record 40 of Set 26 | teguise
# Processing Record 41 of Set 26 | huicheng
# Processing Record 42 of Set 26 | zhangye
# Processing Record 43 of Set 26 | kochkurovo
# Processing Record 44 of Set 26 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 26 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 26 | solenzo
# Processing Record 47 of Set 26 | buala
# Processing Record 48 of Set 26 | el faiyum
# City not found. Skipping...
# Processing Record 49 of Set 26 | jashpurnagar
# Processing Record 50 of Set 26 | podstepki
# Processing Record 1 of Set 27 | cabedelo
# Processing Record 2 of Set 27 | qui nhon
# Processing Record 3 of Set 27 | dakoro
# Processing Record 4 of Set 27 | dawlatabad
# Processing Record 5 of Set 27 | corinto
# Processing Record 6 of Set 27 | kruisfontein
# Processing Record 7 of Set 27 | marystown
# Processing Record 8 of Set 27 | oktyabrskiy
# Processing Record 9 of Set 27 | ukiah
# Processing Record 10 of Set 27 | darhan
# Processing Record 11 of Set 27 | guiratinga
# Processing Record 12 of Set 27 | wuwei
# Processing Record 13 of Set 27 | bandarbeyla
# Processing Record 14 of Set 27 | beisfjord
# Processing Record 15 of Set 27 | nuuk
# Processing Record 16 of Set 27 | corsicana
# Processing Record 17 of Set 27 | nhulunbuy
# Processing Record 18 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 27 | anadyr
# Processing Record 20 of Set 27 | numan
# Processing Record 21 of Set 27 | inirida
# Processing Record 22 of Set 27 | kollam
# Processing Record 23 of Set 27 | tokur
# Processing Record 24 of Set 27 | kankon
# Processing Record 25 of Set 27 | yusva
# City not found. Skipping...
# Processing Record 26 of Set 27 | bairnsdale
# Processing Record 27 of Set 27 | oranjemund
# Processing Record 28 of Set 27 | kachug
# Processing Record 29 of Set 27 | ballina
# Processing Record 30 of Set 27 | yanam
# Processing Record 31 of Set 27 | muli
# Processing Record 32 of Set 27 | springdale
# Processing Record 33 of Set 27 | radhanpur
# Processing Record 34 of Set 27 | ust-tsilma
# Processing Record 35 of Set 27 | tiznit
# Processing Record 36 of Set 27 | cascais
# Processing Record 37 of Set 27 | kangaba
# Processing Record 38 of Set 27 | bereda
# Processing Record 39 of Set 27 | la cruz
# Processing Record 40 of Set 27 | phan thiet
# Processing Record 41 of Set 27 | minuri
# Processing Record 42 of Set 27 | bilma
# Processing Record 43 of Set 27 | cervo
# Processing Record 44 of Set 27 | boshnyakovo
# Processing Record 45 of Set 27 | tiarei
# Processing Record 46 of Set 27 | sitka
# Processing Record 47 of Set 27 | tura
# Processing Record 48 of Set 27 | albania
# Processing Record 49 of Set 27 | la joya
# Processing Record 50 of Set 27 | brae
# Processing Record 1 of Set 28 | meilu
# City not found. Skipping...
# Processing Record 2 of Set 28 | novouzensk
# Processing Record 3 of Set 28 | ballaghaderreen
# Processing Record 4 of Set 28 | rio gallegos
# Processing Record 5 of Set 28 | spisska nova ves
# Processing Record 6 of Set 28 | yashkul
# Processing Record 7 of Set 28 | lakhnadon
# Processing Record 8 of Set 28 | nicoya
# Processing Record 9 of Set 28 | raub
# Processing Record 10 of Set 28 | kurchum
# Processing Record 11 of Set 28 | severnoye
# Processing Record 12 of Set 28 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 28 | kindu
# Processing Record 14 of Set 28 | urumqi
# Processing Record 15 of Set 28 | tambura
# Processing Record 16 of Set 28 | djougou
# Processing Record 17 of Set 28 | ryotsu
# Processing Record 18 of Set 28 | port hardy
# Processing Record 19 of Set 28 | chintamani
# Processing Record 20 of Set 28 | bose
# Processing Record 21 of Set 28 | malabo
# Processing Record 22 of Set 28 | nemuro
# Processing Record 23 of Set 28 | kanungu
# Processing Record 24 of Set 28 | omsukchan
# Processing Record 25 of Set 28 | santa luzia
# Processing Record 26 of Set 28 | kuah
# Processing Record 27 of Set 28 | stephenville
# Processing Record 28 of Set 28 | nara
# Processing Record 29 of Set 28 | safakulevo
# Processing Record 30 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 28 | cobija
# Processing Record 32 of Set 28 | gunnedah
# Processing Record 33 of Set 28 | tautira
# Processing Record 34 of Set 28 | victoria point
# Processing Record 35 of Set 28 | karratha
# Processing Record 36 of Set 28 | seymchan
# Processing Record 37 of Set 28 | gweta
# Processing Record 38 of Set 28 | male
# Processing Record 39 of Set 28 | funchal
# Processing Record 40 of Set 28 | russell
# Processing Record 41 of Set 28 | valley station
# Processing Record 42 of Set 28 | gushikawa
# Processing Record 43 of Set 28 | shatrovo
# Processing Record 44 of Set 28 | yamada
# Processing Record 45 of Set 28 | lipetsk
# Processing Record 46 of Set 28 | te anau
# Processing Record 47 of Set 28 | siavonga
# Processing Record 48 of Set 28 | sumbe
# Processing Record 49 of Set 28 | huangchuan
# Processing Record 50 of Set 28 | lincoln
# Processing Record 1 of Set 29 | paamiut
# Processing Record 2 of Set 29 | atambua
# Processing Record 3 of Set 29 | kilindoni
# Processing Record 4 of Set 29 | polson
# Processing Record 5 of Set 29 | tual
# Processing Record 6 of Set 29 | dasoguz
# Processing Record 7 of Set 29 | gari
# Processing Record 8 of Set 29 | monrovia
# Processing Record 9 of Set 29 | san carlos
# Processing Record 10 of Set 29 | ballangen
# Processing Record 11 of Set 29 | zabol
# Processing Record 12 of Set 29 | havoysund
# Processing Record 13 of Set 29 | guajara-mirim
# City not found. Skipping...
# Processing Record 14 of Set 29 | payo
# Processing Record 15 of Set 29 | kushima
# Processing Record 16 of Set 29 | honningsvag
# Processing Record 17 of Set 29 | svetlogorsk
# Processing Record 18 of Set 29 | saint-joseph
# Processing Record 19 of Set 29 | sahuaripa
# Processing Record 20 of Set 29 | batagay-alyta
# Processing Record 21 of Set 29 | aitape
# Processing Record 22 of Set 29 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 29 | bekobod
# Processing Record 24 of Set 29 | kraslava
# Processing Record 25 of Set 29 | salamiyah
# Processing Record 26 of Set 29 | cabinda
# Processing Record 27 of Set 29 | vila velha
# Processing Record 28 of Set 29 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 29 | port macquarie
# Processing Record 30 of Set 29 | rio tuba
# Processing Record 31 of Set 29 | zaokskiy
# Processing Record 32 of Set 29 | santa catalina
# Processing Record 33 of Set 29 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 29 | saint-augustin
# Processing Record 35 of Set 29 | nouadhibou
# Processing Record 36 of Set 29 | puteyets
# Processing Record 37 of Set 29 | rivers
# Processing Record 38 of Set 29 | tokmak
# Processing Record 39 of Set 29 | yilan
# Processing Record 40 of Set 29 | labutta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 5: Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     70.21        75           6
# 1        Busselton      AU -33.6500  115.3333     51.08        89          43
# 2  Arraial Do Cabo      BR -22.9661  -42.0278     71.31        94         100
# 3          Rikitea      PF -23.1203 -134.9692     73.99        66          29
# 4          Mataura      NZ -46.1927  168.8643     49.48        88          55
# 5           Bethel      US  41.3712  -73.4140     68.49        70          43
# 6             Lata      PT  40.1629   -8.3327     64.04        94          22
# 7            Pisco      PE -13.7000  -76.2167     66.25        82          90
# 8          Cayenne      GF   4.9333  -52.3333     77.09        89           0
# 9         Calvinia      ZA -31.4707   19.7760     41.94        96          13
#
#    Wind Speed Current Description
# 0        7.36           clear sky
# 1        7.49    scattered clouds
# 2        8.66          light rain
# 3       18.01    scattered clouds
# 4        2.73       broken clouds
# 5        3.06    scattered clouds
# 6        2.42          few clouds
# 7        8.05     overcast clouds
# 8       11.52           clear sky
# 9        1.97          few clouds

# %%
# Step 6: Export the DataFrame as a CSV file, and 
# save it as WeatherPy_Database.csv in the Weather_Database folder.

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
